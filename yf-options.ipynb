# %%
import yfinance as yf
import pandas as pd

symbol = "NVDA"  # Example stock symbol, you can change it to any valid ticker
print(symbol)

# Create a ticker object
ticker = yf.Ticker(symbol)  # Example with Apple
info = ticker.info
display(info)
# Out:
# NVDA
# {'address1': '2788 San Tomas Expressway',
#  'city': 'Santa Clara',
#  'state': 'CA',
#  'zip': '95051',
#  'country': 'United States',
#  'phone': '408 486 2000',
#  'website': 'https://www.nvidia.com',
#  'industry': 'Semiconductors',
#  'industryKey': 'semiconductors',
#  'industryDisp': 'Semiconductors',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
# Get available expiration dates
expiration_dates = ticker.options
print(f"Available expiration dates for {symbol}:")
display(expiration_dates)
# Out:
# Available expiration dates for NVDA:
# ('2025-12-26',
#  '2026-01-02',
#  '2026-01-09',
#  '2026-01-16',
#  '2026-01-23',
#  '2026-01-30',
#  '2026-02-20',
#  '2026-03-20',
#  '2026-04-17',
#  '2026-05-15',
#  '2026-06-18',
#  '2026-07-17',
#  '2026-08-21',
#  '2026-09-18',
#  '2026-12-18',
#  '2027-01-15',
#  '2027-06-17',
#  '2027-09-17',
#  '2027-12-17',
#  '2028-01-21')

# %%
expiration = expiration_dates[0]
options_chain = ticker.option_chain()
display(options_chain)
# Out:
# Options(calls=         contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   NVDA251226C00050000 2025-12-19 19:50:38+00:00    50.0     130.65  130.0
# 1   NVDA251226C00055000 2025-12-12 16:09:36+00:00    55.0     122.34  124.3
# 2   NVDA251226C00060000 2025-12-19 15:23:56+00:00    60.0     117.56  119.3
# 3   NVDA251226C00070000 2025-12-19 19:11:21+00:00    70.0     109.94  109.3
# 4   NVDA251226C00075000 2025-12-19 19:32:05+00:00    75.0     105.61  104.3
# ..                  ...                       ...     ...        ...    ...
# 66  NVDA251226C00350000 2025-12-02 15:24:26+00:00   350.0       0.01    0.0
# 67  NVDA251226C00360000 2025-11-21 20:21:11+00:00   360.0       0.01    0.0
# 68  NVDA251226C00370000 2025-11-24 15:14:43+00:00   370.0       0.01    0.0
# 69  NVDA251226C00380000 2025-11-18 19:07:03+00:00   380.0       0.03    0.0
# 70  NVDA251226C00390000 2025-12-18 19:56:14+00:00   390.0       0.01    0.0
#
# ...

# %%
# options_chain contains two DataFrames: calls and puts
print("expiration:", expiration)
display(options_chain.calls)
# Out:
# expiration: 2025-12-26
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   NVDA251226C00050000 2025-12-19 19:50:38+00:00    50.0     130.65  130.0
# 1   NVDA251226C00055000 2025-12-12 16:09:36+00:00    55.0     122.34  124.3
# 2   NVDA251226C00060000 2025-12-19 15:23:56+00:00    60.0     117.56  119.3
# 3   NVDA251226C00070000 2025-12-19 19:11:21+00:00    70.0     109.94  109.3
# 4   NVDA251226C00075000 2025-12-19 19:32:05+00:00    75.0     105.61  104.3
# ..                  ...                       ...     ...        ...    ...
# 66  NVDA251226C00350000 2025-12-02 15:24:26+00:00   350.0       0.01    0.0
# 67  NVDA251226C00360000 2025-11-21 20:21:11+00:00   360.0       0.01    0.0
# 68  NVDA251226C00370000 2025-11-24 15:14:43+00:00   370.0       0.01    0.0
# 69  NVDA251226C00380000 2025-11-18 19:07:03+00:00   380.0       0.03    0.0
# 70  NVDA251226C00390000 2025-12-18 19:56:14+00:00   390.0       0.01    0.0
#
# ...

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from statistics import mean

# %%
tickerSymbol = 'SMH'

# Get data on this ticker
tickerData = yf.Ticker(tickerSymbol)
df = tickerData.option_chain()
display(df.calls)
# bid & ask prices all 0
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   SMH251017C00100000 2025-10-13 14:05:26+00:00   100.0     239.30  235.85
# 1   SMH251017C00105000 2025-10-13 14:05:52+00:00   105.0     234.31  230.80
# 2   SMH251017C00110000 2025-10-13 13:30:22+00:00   110.0     223.39  226.05
# 3   SMH251017C00115000 2025-10-14 13:33:05+00:00   115.0     217.96  220.75
# 4   SMH251017C00120000 2025-10-14 13:32:44+00:00   120.0     213.58  216.40
# ..                 ...                       ...     ...        ...     ...
# 73  SMH251017C00390000 2025-10-14 16:13:21+00:00   390.0       0.02    0.02
# 74  SMH251017C00400000 2025-10-14 16:12:58+00:00   400.0       0.01    0.01
# 75  SMH251017C00410000 2025-10-14 14:14:56+00:00   410.0       0.02    0.00
# 76  SMH251017C00420000 2025-10-06 14:17:27+00:00   420.0       0.05    0.00
# 77  SMH251017C00430000 2025-10-06 13:56:23+00:00   430.0       0.01     NaN
#
# ...

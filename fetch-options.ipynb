# %%
import yfinance as yf
import pandas as pd
from datetime import date
from time import sleep
from glob import glob
import os
import json
from symbols import etfs_with_weekly_options

# %%
def fetch_options(expiration, symbols):
    count = 0
    for symbol in symbols:
        dir = f'data/options/{symbol}/{expiration}'
        if os.path.exists(dir):
            # print(f'{dir} already exists, skipping')
            continue
        os.makedirs(dir)

        print(f'Fetching {symbol} options for {expiration}')
        sleep(2)  # Sleep to avoid hitting API rate limits
        ticker = yf.Ticker(symbol)
        expirations = ticker.options
        pd.DataFrame({'Expiration': expirations}).to_csv(f'{dir}/expirations.csv', index=False)
        if not expiration in expirations:
            print(f'No {symbol} options for {expiration}')
            continue
        chain = ticker.option_chain(expiration)
        print(f'Found {len(chain.calls)} calls and {len(chain.puts)} puts for {symbol} on {expiration}')
        chain.calls.to_csv(f'{dir}/calls.csv', index=False)
        chain.puts.to_csv(f'{dir}/puts.csv', index=False)
        with open(f'{dir}/underlying.json', 'w') as f:
          json.dump(chain.underlying, f, indent=2, sort_keys=True)
        count += 1

    print(f'Fetched options for {count}/{len(symbols)} symbols on {expiration}')

# etfs = pd.read_csv('data/top-etfs.csv')
# fetch_options('2025-05-30', etfs['Symbol'].to_list())
# sp500 = pd.read_csv('data/sp500_stocks.csv')
# fetch_options('2025-05-30', sp500['Symbol'].to_list())


fetch_options('2025-08-01', etfs_with_weekly_options)
# Out:
# Fetching EWZ options for 2025-08-01
# Found 13 calls and 13 puts for EWZ on 2025-08-01
# Fetching EEM options for 2025-08-01
# Found 13 calls and 12 puts for EEM on 2025-08-01
# Fetching XLF options for 2025-08-01
# Found 22 calls and 29 puts for XLF on 2025-08-01
# Fetching KWEB options for 2025-08-01
# Found 26 calls and 21 puts for KWEB on 2025-08-01
# Fetching SILJ options for 2025-08-01
# Found 13 calls and 8 puts for SILJ on 2025-08-01
# Fetching ARKK options for 2025-08-01
# Found 61 calls and 60 puts for ARKK on 2025-08-01
# Fetching VTI options for 2025-08-01
# Found 21 calls and 16 puts for VTI on 2025-08-01
# Fetching ASHR options for 2025-08-01
# Found 12 calls and 11 puts for ASHR on 2025-08-01
# Fetching AGQ options for 2025-08-01
# Found 34 calls and 28 puts for AGQ on 2025-08-01
# Fetching BITO options for 2025-08-01
# Found 19 calls and 27 puts for BITO on 2025-08-01
# Fetching GDX options for 2025-08-01
# Found 35 calls and 29 puts for GDX on 2025-08-01
# Fetching FXI options for 2025-08-01
# Found 21 calls and 21 puts for FXI on 2025-08-01
# Fetching IVV options for 2025-08-01
# Found 26 calls and 26 puts for IVV on 2025-08-01
# Fetching ETHA options for 2025-08-01
# Found 39 calls and 34 puts for ETHA on 2025-08-01
# Fetching IBIT options for 2025-08-01
# Found 64 calls and 59 puts for IBIT on 2025-08-01
# Fetching SCHD options for 2025-08-01
# Found 13 calls and 8 puts for SCHD on 2025-08-01
# Fetching EFA options for 2025-08-01
# Found 14 calls and 18 puts for EFA on 2025-08-01
# Fetching BITX options for 2025-08-01
# Found 57 calls and 49 puts for BITX on 2025-08-01
# Fetching FEZ options for 2025-08-01
# Found 3 calls and 8 puts for FEZ on 2025-08-01
# Fetching YINN options for 2025-08-01
# Found 33 calls and 37 puts for YINN on 2025-08-01
# Fetching FBTC options for 2025-08-01
# Found 40 calls and 35 puts for FBTC on 2025-08-01
# Fetching MAGS options for 2025-08-01
# Found 20 calls and 22 puts for MAGS on 2025-08-01
# Fetching JETS options for 2025-08-01
# Found 16 calls and 20 puts for JETS on 2025-08-01
# Fetching XOP options for 2025-08-01
# Found 36 calls and 35 puts for XOP on 2025-08-01
# Fetching ARKG options for 2025-08-01
# Found 19 calls and 13 puts for ARKG on 2025-08-01
# Fetching TQQQ options for 2025-08-01
# Found 51 calls and 48 puts for TQQQ on 2025-08-01
# Fetching GDXJ options for 2025-08-01
# Found 38 calls and 30 puts for GDXJ on 2025-08-01
# Fetching SLV options for 2025-08-01
# Found 31 calls and 25 puts for SLV on 2025-08-01
# Fetching QQQ options for 2025-08-01
# Found 112 calls and 112 puts for QQQ on 2025-08-01
# Fetching TNA options for 2025-08-01
# Found 36 calls and 36 puts for TNA on 2025-08-01
# Fetching TLT options for 2025-08-01
# Found 42 calls and 41 puts for TLT on 2025-08-01
# Fetching SQQQ options for 2025-08-01
# Found 32 calls and 29 puts for SQQQ on 2025-08-01
# Fetching IEF options for 2025-08-01
# Found 13 calls and 13 puts for IEF on 2025-08-01
# Fetching IWM options for 2025-08-01
# Found 73 calls and 69 puts for IWM on 2025-08-01
# Fetching NUGT options for 2025-08-01
# Found 45 calls and 43 puts for NUGT on 2025-08-01
# Fetching SOXL options for 2025-08-01
# Found 41 calls and 37 puts for SOXL on 2025-08-01
# Fetching FAS options for 2025-08-01
# Found 40 calls and 39 puts for FAS on 2025-08-01
# Fetching ITB options for 2025-08-01
# Found 30 calls and 36 puts for ITB on 2025-08-01
# Fetching SPY options for 2025-08-01
# Found 114 calls and 122 puts for SPY on 2025-08-01
# Fetching XBI options for 2025-08-01
# Found 38 calls and 34 puts for XBI on 2025-08-01
# Fetching DIA options for 2025-08-01
# Found 78 calls and 78 puts for DIA on 2025-08-01
# Fetching UPRO options for 2025-08-01
# Found 42 calls and 46 puts for UPRO on 2025-08-01
# Fetching SVIX options for 2025-08-01
# Found 13 calls and 12 puts for SVIX on 2025-08-01
# Fetching HYG options for 2025-08-01
# Found 9 calls and 13 puts for HYG on 2025-08-01
# Fetching XLK options for 2025-08-01
# Found 29 calls and 24 puts for XLK on 2025-08-01
# Fetching SPXL options for 2025-08-01
# Found 50 calls and 53 puts for SPXL on 2025-08-01
# Fetching TSLL options for 2025-08-01
# Found 42 calls and 38 puts for TSLL on 2025-08-01
# Fetching USO options for 2025-08-01
# Found 51 calls and 56 puts for USO on 2025-08-01
# Fetching SSO options for 2025-08-01
# Found 24 calls and 26 puts for SSO on 2025-08-01
# Fetching VOO options for 2025-08-01
# Found 44 calls and 31 puts for VOO on 2025-08-01
# Fetching SVXY options for 2025-08-01
# Found 14 calls and 16 puts for SVXY on 2025-08-01
# Fetching SPXU options for 2025-08-01
# Found 14 calls and 13 puts for SPXU on 2025-08-01
# Fetching SMH options for 2025-08-01
# Found 45 calls and 52 puts for SMH on 2025-08-01
# Fetching IGV options for 2025-08-01
# Found 20 calls and 16 puts for IGV on 2025-08-01
# Fetching XLY options for 2025-08-01
# Found 15 calls and 16 puts for XLY on 2025-08-01
# Fetching TMF options for 2025-08-01
# Found 29 calls and 32 puts for TMF on 2025-08-01
# Fetching IAU options for 2025-08-01
# Found 20 calls and 13 puts for IAU on 2025-08-01
# Fetching GLD options for 2025-08-01
# Found 82 calls and 60 puts for GLD on 2025-08-01
# Fetching RSP options for 2025-08-01
# Found 18 calls and 21 puts for RSP on 2025-08-01
# Fetching KRE options for 2025-08-01
# Found 29 calls and 32 puts for KRE on 2025-08-01
# Fetching XLV options for 2025-08-01
# Found 27 calls and 30 puts for XLV on 2025-08-01
# Fetched options for 61/61 symbols on 2025-08-01

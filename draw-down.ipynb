# %%
import pandas as pd
import yfinance as yf
from datetime import date

# %%
# Define the ticker symbol
tickerSymbol = 'IYW'

# Get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

# Get the historical prices for this ticker
history = tickerData.history(interval='1wk', start='2021-1-1', end=date.today())

# %%
weeks = 4
history['WLow'] = history.Low.rolling(window=pd.api.indexers.FixedForwardWindowIndexer(window_size=weeks)).min().shift(-1)
history['DrawDown'] = history.WLow / history.Close - 1
print(f'{tickerSymbol} {weeks}w median draw down {history.DrawDown.median():.1%}')
display(history)
# Out:
# IYW 4w median draw down -3.6%
#                                  Open        High         Low       Close  \
# Date
# 2021-01-01 00:00:00-05:00   84.353971   84.423008   81.533295   84.196175
# 2021-01-08 00:00:00-05:00   84.758331   85.044345   83.160603   83.870705
# 2021-01-15 00:00:00-05:00   83.910157   87.756534   82.992945   87.519829
# 2021-01-22 00:00:00-05:00   87.184521   88.999218   85.379681   86.543457
# 2021-01-29 00:00:00-05:00   86.010883   89.354271   83.998932   89.354271
# ...                               ...         ...         ...         ...
# 2024-07-26 00:00:00-04:00  144.539993  147.899994  140.160004  141.770004
# 2024-08-02 00:00:00-04:00  138.309998  139.639999  127.919998  137.919998
# 2024-08-09 00:00:00-04:00  137.570007  147.839996  137.080002  147.710007
# 2024-08-16 00:00:00-04:00  147.089996  151.339996  146.589996  147.360001
# 2024-08-23 00:00:00-04:00  148.699997  150.149994  147.660004  149.380005
#
# ...
